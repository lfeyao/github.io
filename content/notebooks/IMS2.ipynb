# %%
# %matplotlib inline
import pandas as pd
pd.options.display.float_format = '${:,.0f}'.format
import numpy as np
import matplotlib.pyplot as plt

# %%
imsdata = pd.read_csv('imsdata3.csv')

# %%
imsdata.head()
# Out:
#   Molecule                         ATC3                          USC3  \
# 0      NaN  A06A DRUGS FOR CONSTIPATION          56100 FECAL SOFTENER
# 1      NaN  A06A DRUGS FOR CONSTIPATION  56200 IRRITANT-STIMULANT LAX
# 2      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
# 3      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
# 4      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
#
#              Form  Brand       Product        Manufacturer PATEXP Strength  \
# 0         O ORALS  OTHER  DOCUSATE SOD  TEVA PHARMACEUTICA    NaN      NaN
# 1  R RECTALS,SYST  OTHER      GLYCERIN       PRIVATE LABEL    NaN      NaN
# 2         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN     100%
# 3         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN   28.30%
# 4         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN      NaN
#
#   2009_Sales   2010_Sales   2011_Sales   2012_Sales   2013_Sales   2014_Sales  \
# 0    $7,750      $18,614         $142           NaN          NaN          NaN
# 1  $302,843   $2,875,694   $1,923,251   $1,122,809   $1,366,640   $1,437,626
# 2        NaN          NaN          NaN          NaN          NaN     $49,825
# 3        NaN          NaN          NaN          NaN          NaN    $109,692
# 4    $4,312      $51,489      $48,564      $35,569      $75,630     $541,313
#
#     2015_Sales
# 0          NaN
# 1  $1,215,119
# 2    $110,749
# 3    $114,653
# 4    $496,608

# %%
imsdata['2009_Sales'] = imsdata['2009_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2010_Sales'] = imsdata['2010_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2011_Sales'] = imsdata['2011_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2012_Sales'] = imsdata['2012_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2013_Sales'] = imsdata['2013_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2014_Sales'] = imsdata['2014_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)
imsdata['2015_Sales'] = imsdata['2015_Sales'].str.replace(',', '').str.replace('$', '').str.strip().astype(float)

# %%
imsdata.head()
# Out:
#   Molecule                         ATC3                          USC3  \
# 0      NaN  A06A DRUGS FOR CONSTIPATION          56100 FECAL SOFTENER
# 1      NaN  A06A DRUGS FOR CONSTIPATION  56200 IRRITANT-STIMULANT LAX
# 2      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
# 3      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
# 4      NaN  A06A DRUGS FOR CONSTIPATION      56300 BULK-PRODUCING LAX
#
#              Form  Brand       Product        Manufacturer PATEXP Strength  \
# 0         O ORALS  OTHER  DOCUSATE SOD  TEVA PHARMACEUTICA    NaN      NaN
# 1  R RECTALS,SYST  OTHER      GLYCERIN       PRIVATE LABEL    NaN      NaN
# 2         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN     100%
# 3         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN   28.30%
# 4         O ORALS  OTHER        KONSYL   KONSYL PHARMACEUT    NaN      NaN
#
#    2009_Sales  2010_Sales  2011_Sales  2012_Sales  2013_Sales  2014_Sales  \
# 0      $7,750     $18,614        $142        $nan        $nan        $nan
# 1    $302,843  $2,875,694  $1,923,251  $1,122,809  $1,366,640  $1,437,626
# 2        $nan        $nan        $nan        $nan        $nan     $49,825
# 3        $nan        $nan        $nan        $nan        $nan    $109,692
# 4      $4,312     $51,489     $48,564     $35,569     $75,630    $541,313
#
#    2015_Sales
# 0        $nan
# 1  $1,215,119
# 2    $110,749
# 3    $114,653
# 4    $496,608

# %%
molecule = 'FENOFIBRATE'
strength = ['145MG', '48MG']
drugtype = ['GENERIC']
form = 'O ORALS'

# %%
selected_df = imsdata[(imsdata.Strength.isin(strength)) & (imsdata.Form == form) & (imsdata.Molecule == molecule)]
selected_df.head()
# Out:
#           Molecule                           ATC3                   USC3  \
# 13806  FENOFIBRATE  C10A CHOLEST&TRIGLY.REGULATOR  32100 CHOLESTEROL RED
# 13807  FENOFIBRATE  C10A CHOLEST&TRIGLY.REGULATOR  32100 CHOLESTEROL RED
# 13824  FENOFIBRATE  C10A CHOLEST&TRIGLY.REGULATOR  32100 CHOLESTEROL RED
# 13827  FENOFIBRATE  C10A CHOLEST&TRIGLY.REGULATOR  32100 CHOLESTEROL RED
# 13833  FENOFIBRATE  C10A CHOLEST&TRIGLY.REGULATOR  32100 CHOLESTEROL RED
#
#           Form    Brand      Product       Manufacturer  PATEXP Strength  \
# 13806  O ORALS    BRAND       TRICOR        ABBVIE INC.  Apr-02    145MG
# 13807  O ORALS    BRAND       TRICOR        ABBVIE INC.  Apr-02     48MG
# 13824  O ORALS  GENERIC  FENOFIBRATE  AMERICAN HLTH PKG     NaN    145MG
# 13827  O ORALS  GENERIC  FENOFIBRATE  AMERICAN HLTH PKG     NaN     48MG
# 13833  O ORALS  GENERIC  FENOFIBRATE     A-S MEDICATION     NaN     48MG
#
#         2009_Sales     2010_Sales     2011_Sales     2012_Sales   2013_Sales  \
# 13806 $140,700,914 $1,357,527,213 $1,335,165,105 $1,076,304,398 $126,002,678
# 13807   $7,056,250    $70,240,209    $70,967,942    $58,842,306   $4,332,930
# 13824         $nan           $nan           $nan           $nan   $1,361,154
# 13827         $nan           $nan           $nan           $nan     $189,841
# 13833         $nan           $nan           $nan           $nan         $nan
#
#         2014_Sales  2015_Sales
# 13806 $121,215,552 $90,547,045
# 13807   $3,473,121  $1,940,280
# 13824   $1,264,923    $700,634
# 13827     $181,249    $115,977
# 13833       $4,340      $4,903

# %%
selected_df['2015_Sales'] = selected_df['2015_Sales'] * 4/3
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bybrand_df = selected_df.groupby('Brand')
bybrand_df.sum()
# Out:
#           2009_Sales     2010_Sales     2011_Sales     2012_Sales  \
# Brand
# BRAND   $147,757,164 $1,427,767,422 $1,406,133,047 $1,135,146,704
# GENERIC         $nan           $nan           $nan   $117,345,935
#
#           2013_Sales   2014_Sales   2015_Sales
# Brand
# BRAND   $130,335,608 $124,688,673 $123,316,433
# GENERIC $602,210,023 $468,418,121 $354,221,520

# %%
byproduct_df = selected_df.groupby('Product')
byproduct_df.sum()
# Out:
#               2009_Sales     2010_Sales     2011_Sales     2012_Sales  \
# Product
# FENOFIBRATE         $nan           $nan           $nan   $117,345,935
# TRICOR      $147,757,164 $1,427,767,422 $1,406,133,047 $1,135,146,704
#
#               2013_Sales   2014_Sales   2015_Sales
# Product
# FENOFIBRATE $602,210,023 $468,418,121 $354,221,520
# TRICOR      $130,335,608 $124,688,673 $123,316,433

# %%
ax = bybrand_df.sum().transpose().plot(kind='bar', stacked=True)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
ax = byproduct_df.sum().transpose().plot(kind='bar', stacked=True)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
ax = bymanu_df.sum().transpose().plot(kind='bar', stacked=True)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
type_df = imsdata.groupby('ATC3')
typesum_df = type_df.sum()

# %%
typesum_df.sort_values('2015_Sales', ascending = False)
# Out:
#                                      2009_Sales      2010_Sales  \
# ATC3
# A10C HUMAN INSULIN+ANALOGUES       $742,079,926  $8,839,139,374
# L04B ANTI-TNF PRODUCTS             $901,405,875 $10,307,786,502
# J05B ANTIVIRALS EXCL ANTI-HIV      $364,628,590  $3,259,218,483
# J05C HIV ANTIVIRALS                $838,449,602  $9,361,722,160
# N05A ANTIPSYCHOTICS              $1,459,445,588 $16,313,933,635
# L01G MAB ANTINEOPLASTICS           $775,466,245  $8,327,409,055
# C10A CHOLEST&TRIGLY.REGULATOR    $1,611,076,334 $17,869,762,169
# N03A ANTI-EPILEPTICS               $562,699,135  $5,744,242,911
# L03A IMMUNOSTIM AG EX INTFRON      $568,608,559  $6,613,290,644
# L01H PROTEIN KINASE INH A-NEO      $241,684,926  $2,955,797,379
# N06B PSYCHOSTIMULANTS              $597,512,843  $6,818,116,496
# N02A NARCOTIC ANALGESICS           $811,640,663  $8,463,964,080
# R03F B2-STIMULANTS+CORTICOIDS      $549,520,533  $6,049,238,716
# A02B ANTIULCERANTS               $1,250,344,211 $12,899,609,092
# L04X OTHER IMMUNOSUPPRESSANTS      $253,225,425  $2,814,007,313
# A10N DPP-IV INHIB ANTIDIAB         $209,290,894  $2,660,315,158
# N07X ALL OTHER CNS DRUGS            $78,479,069  $1,056,385,597
# N06A ANTIDEPRESS.& MOOD STAB.    $1,114,790,703 $11,930,272,075
# G03A HORMONAL CONTRACEPT SYST      $441,972,265  $4,832,167,207
# R03G ANTICHOLINERGIC+B2-STIM       $287,234,413  $3,351,411,481
# L03B INTERFERONS                   $312,838,538  $3,546,741,377
# J07E VIRAL VACCINES                $250,298,291  $3,136,738,705
# T02D DIABETES TEST                 $352,498,215  $3,740,369,928
# B03C ERYTHROPOIETIN PRODUCTS       $596,696,011  $6,119,582,714
# B01F DIRECT FACTOR XA INHIBITORS           $nan            $nan
# R03A B2-STIMULANTS                 $284,106,805  $2,935,422,804
# R03D CORTICOIDS                    $304,359,876  $2,608,827,766
# A10S GLP-1 AGONIST ANTIDIAB         $61,978,790    $844,787,962
# A07E INTESTINAL ANTI-INFLAMM       $168,280,644  $1,950,885,436
# G04E ERECTILE DYSFUNCTION PRD      $196,471,259  $2,057,606,145
# ...                                         ...             ...
# G03X OTH.SEX HORM.&SIMILAR             $702,545      $7,124,438
# K02B STARCHES                        $1,606,515     $20,706,084
# J03A SYSTEMIC SULPHONAMIDES            $522,225      $5,843,966
# K05A IRRIGATING SOLUTIONS              $264,094      $2,976,474
# T01G RADIODIAGNOSTIC AGENTS                $nan            $nan
# R03C N-STEROIDAL RESP A-INFL           $251,509      $2,281,054
# A07X OTHER ANTIDIARRHOEALS               $1,274         $53,900
# K01A ELECTROLYTE SOLN=>100ML           $382,097      $3,764,913
# G01D GYNAECOLOG ANTISEPTICS             $33,917        $316,459
# C05B VARICOSE THERAPY,TOPICAL          $449,584      $2,792,942
# J06G SPECF IMM-GLOB ANTI-BACT          $712,770      $4,821,608
# N06D NOOTROPICS                            $nan            $nan
# C02B A-HYPERT(NON VEG)+DIURET          $106,147      $1,003,446
# K01B STANDARD SOLUTIONS                 $78,477      $1,209,659
# K01E AMINO-ACID SOLUTIONS               $14,748        $278,890
# H03C IODINE PREPARATIONS                $37,436      $1,412,212
# K02A DEXTRANS                          $138,420      $1,774,903
# A02C OTH STOMACH DISORDER PRD           $27,576        $438,167
# K07A PERFUSION SOLUTIONS                $28,917        $191,961
# J01L CARBENICILLIN+SIMIL.TYPE          $981,542      $9,009,489
# K04B STANDARD SOLUTION <100ML           $25,860        $216,454
# P03B INSECTICIDES & REPELLENTS             $nan            $319
# C02C RAUWLF ALK+OTH A-HY HERB           $95,011      $1,037,018
# K04C CALORIC SOLUTIONS <100ML                $3            $218
# A03E A-SPASMA COMBINATIONS              $20,878        $225,224
# A10D ANIMAL INSULINS                       $nan            $nan
# A15A APPETITE STIMULANTS                 $8,207        $106,213
# J01B CHLORAMPHENICOLS + COMBS           $26,328        $418,272
# J01M RIFAMPICIN AND RIFAMYCIN              $nan            $nan
# S01N ANTICATARACTOGENICS                 $2,290         $23,884
#
#                                       2011_Sales      2012_Sales  \
# ATC3
# A10C HUMAN INSULIN+ANALOGUES     $10,368,543,405 $12,029,319,586
# L04B ANTI-TNF PRODUCTS           $11,599,115,081 $13,291,287,167
# J05B ANTIVIRALS EXCL ANTI-HIV     $3,783,147,071  $4,416,735,597
# J05C HIV ANTIVIRALS              $10,425,568,102 $11,362,532,422
# N05A ANTIPSYCHOTICS              $18,445,943,730 $13,272,796,233
# L01G MAB ANTINEOPLASTICS          $8,585,636,903  $9,130,107,622
# C10A CHOLEST&TRIGLY.REGULATOR    $19,654,414,518 $15,190,739,932
# N03A ANTI-EPILEPTICS              $6,023,663,290  $6,066,664,715
# L03A IMMUNOSTIM AG EX INTFRON     $7,725,432,494  $8,179,401,022
# L01H PROTEIN KINASE INH A-NEO     $3,661,904,516  $4,602,790,110
# N06B PSYCHOSTIMULANTS             $7,976,391,249  $8,930,754,357
# N02A NARCOTIC ANALGESICS          $8,334,870,709  $8,198,608,478
# R03F B2-STIMULANTS+CORTICOIDS     $6,264,401,811  $6,595,761,925
# A02B ANTIULCERANTS               $10,995,409,144 $10,220,295,809
# L04X OTHER IMMUNOSUPPRESSANTS     $3,409,174,388  $4,006,017,323
# A10N DPP-IV INHIB ANTIDIAB        $3,490,233,933  $4,427,911,104
# N07X ALL OTHER CNS DRUGS          $1,334,038,125  $1,654,719,703
# N06A ANTIDEPRESS.& MOOD STAB.    $11,288,913,834  $9,613,659,445
# G03A HORMONAL CONTRACEPT SYST     $5,197,518,929  $5,379,145,035
# R03G ANTICHOLINERGIC+B2-STIM      $3,878,841,608  $4,131,978,073
# L03B INTERFERONS                  $3,858,289,859  $4,252,865,062
# J07E VIRAL VACCINES               $3,320,007,856  $3,734,589,368
# T02D DIABETES TEST                $3,794,634,292  $3,758,750,328
# B03C ERYTHROPOIETIN PRODUCTS      $5,146,513,592  $4,175,084,291
# B01F DIRECT FACTOR XA INHIBITORS     $17,031,766    $256,391,468
# R03A B2-STIMULANTS                $3,133,424,137  $3,239,213,273
# R03D CORTICOIDS                   $2,891,419,706  $3,083,902,172
# A10S GLP-1 AGONIST ANTIDIAB       $1,204,950,250  $1,603,099,752
# A07E INTESTINAL ANTI-INFLAMM      $2,216,173,210  $2,215,923,998
# G04E ERECTILE DYSFUNCTION PRD     $2,162,266,078  $2,236,891,610
# ...                                          ...             ...
# G03X OTH.SEX HORM.&SIMILAR            $6,802,315      $6,929,617
# K02B STARCHES                        $20,642,050     $22,368,919
# J03A SYSTEMIC SULPHONAMIDES           $6,032,996      $6,039,299
# K05A IRRIGATING SOLUTIONS             $2,938,666      $2,839,832
# T01G RADIODIAGNOSTIC AGENTS                 $nan        $639,600
# R03C N-STEROIDAL RESP A-INFL          $1,618,751      $1,732,835
# A07X OTHER ANTIDIARRHOEALS               $35,729         $46,092
# K01A ELECTROLYTE SOLN=>100ML          $2,326,795      $2,198,333
# G01D GYNAECOLOG ANTISEPTICS           $4,376,518      $1,415,275
# C05B VARICOSE THERAPY,TOPICAL         $3,973,397      $8,062,444
# J06G SPECF IMM-GLOB ANTI-BACT         $7,102,153      $4,860,107
# N06D NOOTROPICS                          $38,187        $301,779
# C02B A-HYPERT(NON VEG)+DIURET         $1,092,611      $1,242,050
# K01B STANDARD SOLUTIONS                 $730,649        $579,845
# K01E AMINO-ACID SOLUTIONS               $314,121        $226,097
# H03C IODINE PREPARATIONS              $2,164,102      $1,304,628
# K02A DEXTRANS                         $1,338,152      $1,504,886
# A02C OTH STOMACH DISORDER PRD           $472,649        $377,113
# K07A PERFUSION SOLUTIONS                 $23,940         $29,616
# J01L CARBENICILLIN+SIMIL.TYPE         $6,086,181      $3,133,312
# K04B STANDARD SOLUTION <100ML         $2,153,489         $13,142
# P03B INSECTICIDES & REPELLENTS              $525          $2,137
# C02C RAUWLF ALK+OTH A-HY HERB           $888,547        $549,178
# K04C CALORIC SOLUTIONS <100ML                $35             $90
# A03E A-SPASMA COMBINATIONS              $275,724        $348,084
# A10D ANIMAL INSULINS                        $nan            $nan
# A15A APPETITE STIMULANTS                 $37,557            $343
# J01B CHLORAMPHENICOLS + COMBS           $425,949        $583,323
# J01M RIFAMPICIN AND RIFAMYCIN               $nan            $nan
# S01N ANTICATARACTOGENICS                 $12,811            $nan
#
#                                       2013_Sales      2014_Sales  \
# ATC3
# A10C HUMAN INSULIN+ANALOGUES     $15,409,739,180 $20,472,938,207
# L04B ANTI-TNF PRODUCTS           $15,632,559,151 $19,523,048,388
# J05B ANTIVIRALS EXCL ANTI-HIV     $3,583,822,947 $14,057,523,775
# J05C HIV ANTIVIRALS              $12,481,200,605 $14,342,715,015
# N05A ANTIPSYCHOTICS              $12,363,887,855 $14,595,378,779
# L01G MAB ANTINEOPLASTICS          $9,853,747,190 $11,230,992,713
# C10A CHOLEST&TRIGLY.REGULATOR    $12,535,464,617 $12,694,372,883
# N03A ANTI-EPILEPTICS              $7,193,795,755  $8,509,607,219
# L03A IMMUNOSTIM AG EX INTFRON     $8,604,649,157  $9,052,907,185
# L01H PROTEIN KINASE INH A-NEO     $5,735,995,613  $7,479,903,265
# N06B PSYCHOSTIMULANTS             $8,362,893,489  $8,325,607,275
# N02A NARCOTIC ANALGESICS          $8,283,624,184  $8,855,397,919
# R03F B2-STIMULANTS+CORTICOIDS     $7,537,576,296  $8,152,466,357
# A02B ANTIULCERANTS               $10,533,571,606  $9,718,105,249
# L04X OTHER IMMUNOSUPPRESSANTS     $5,130,979,450  $6,842,505,598
# A10N DPP-IV INHIB ANTIDIAB        $5,290,779,829  $6,477,965,596
# N07X ALL OTHER CNS DRUGS          $3,084,354,356  $5,640,242,676
# N06A ANTIDEPRESS.& MOOD STAB.     $9,302,004,426  $6,868,586,539
# G03A HORMONAL CONTRACEPT SYST     $5,386,697,726  $5,346,349,146
# R03G ANTICHOLINERGIC+B2-STIM      $4,412,799,409  $4,733,172,409
# L03B INTERFERONS                  $4,825,627,668  $4,713,002,069
# J07E VIRAL VACCINES               $4,178,961,033  $4,666,146,125
# T02D DIABETES TEST                $3,966,071,363  $4,155,525,929
# B03C ERYTHROPOIETIN PRODUCTS      $4,153,201,377  $4,226,034,914
# B01F DIRECT FACTOR XA INHIBITORS  $1,125,280,477  $2,616,374,746
# R03A B2-STIMULANTS                $3,303,831,241  $3,561,669,607
# R03D CORTICOIDS                   $3,444,502,714  $3,681,024,019
# A10S GLP-1 AGONIST ANTIDIAB       $2,077,394,829  $2,673,656,401
# A07E INTESTINAL ANTI-INFLAMM      $2,452,171,127  $2,825,894,007
# G04E ERECTILE DYSFUNCTION PRD     $2,572,906,391  $2,966,493,044
# ...                                          ...             ...
# G03X OTH.SEX HORM.&SIMILAR            $6,114,339      $4,958,442
# K02B STARCHES                        $14,083,080      $6,239,741
# J03A SYSTEMIC SULPHONAMIDES           $6,646,640      $5,702,515
# K05A IRRIGATING SOLUTIONS             $2,753,392      $2,995,908
# T01G RADIODIAGNOSTIC AGENTS           $3,456,960      $2,982,200
# R03C N-STEROIDAL RESP A-INFL          $1,871,087      $2,186,784
# A07X OTHER ANTIDIARRHOEALS            $1,208,338      $2,550,117
# K01A ELECTROLYTE SOLN=>100ML            $526,589      $1,208,929
# G01D GYNAECOLOG ANTISEPTICS           $1,431,201      $2,096,224
# C05B VARICOSE THERAPY,TOPICAL         $4,830,263      $2,193,026
# J06G SPECF IMM-GLOB ANTI-BACT         $2,639,025      $1,717,991
# N06D NOOTROPICS                         $771,328      $1,131,840
# C02B A-HYPERT(NON VEG)+DIURET         $1,250,800      $1,167,913
# K01B STANDARD SOLUTIONS                 $535,163        $887,939
# K01E AMINO-ACID SOLUTIONS               $418,660        $669,609
# H03C IODINE PREPARATIONS                $645,194      $1,034,800
# K02A DEXTRANS                         $1,104,920        $354,925
# A02C OTH STOMACH DISORDER PRD           $400,188        $377,728
# K07A PERFUSION SOLUTIONS                 $28,127        $140,705
# J01L CARBENICILLIN+SIMIL.TYPE         $1,828,937      $2,100,345
# K04B STANDARD SOLUTION <100ML             $5,086          $4,071
# P03B INSECTICIDES & REPELLENTS            $2,152          $3,009
# C02C RAUWLF ALK+OTH A-HY HERB             $1,391            $448
# K04C CALORIC SOLUTIONS <100ML               $113              $7
# A03E A-SPASMA COMBINATIONS              $139,144            $538
# A10D ANIMAL INSULINS                        $nan         $11,358
# A15A APPETITE STIMULANTS                    $nan            $nan
# J01B CHLORAMPHENICOLS + COMBS           $324,733            $nan
# J01M RIFAMPICIN AND RIFAMYCIN             $2,872            $nan
# S01N ANTICATARACTOGENICS                    $nan            $nan
#
#                                       2015_Sales
# ATC3
# A10C HUMAN INSULIN+ANALOGUES     $18,267,383,173
# L04B ANTI-TNF PRODUCTS           $17,611,642,263
# J05B ANTIVIRALS EXCL ANTI-HIV    $15,783,499,059
# J05C HIV ANTIVIRALS              $12,249,956,153
# N05A ANTIPSYCHOTICS              $10,949,869,451
# L01G MAB ANTINEOPLASTICS          $9,945,900,325
# C10A CHOLEST&TRIGLY.REGULATOR     $9,394,372,968
# N03A ANTI-EPILEPTICS              $7,436,970,595
# L03A IMMUNOSTIM AG EX INTFRON     $7,426,129,886
# L01H PROTEIN KINASE INH A-NEO     $6,991,640,910
# N06B PSYCHOSTIMULANTS             $6,684,808,696
# N02A NARCOTIC ANALGESICS          $6,667,318,523
# R03F B2-STIMULANTS+CORTICOIDS     $6,642,387,359
# A02B ANTIULCERANTS                $6,419,058,846
# L04X OTHER IMMUNOSUPPRESSANTS     $6,038,477,363
# A10N DPP-IV INHIB ANTIDIAB        $5,802,403,288
# N07X ALL OTHER CNS DRUGS          $5,074,300,641
# N06A ANTIDEPRESS.& MOOD STAB.     $4,257,404,931
# G03A HORMONAL CONTRACEPT SYST     $4,176,768,585
# R03G ANTICHOLINERGIC+B2-STIM      $3,898,155,670
# L03B INTERFERONS                  $3,751,979,572
# J07E VIRAL VACCINES               $3,544,011,070
# T02D DIABETES TEST                $3,308,853,329
# B03C ERYTHROPOIETIN PRODUCTS      $3,185,703,803
# B01F DIRECT FACTOR XA INHIBITORS  $3,068,029,527
# R03A B2-STIMULANTS                $2,928,384,141
# R03D CORTICOIDS                   $2,831,089,879
# A10S GLP-1 AGONIST ANTIDIAB       $2,659,330,472
# A07E INTESTINAL ANTI-INFLAMM      $2,582,281,872
# G04E ERECTILE DYSFUNCTION PRD     $2,471,040,341
# ...                                          ...
# G03X OTH.SEX HORM.&SIMILAR            $4,709,047
# K02B STARCHES                         $4,272,752
# J03A SYSTEMIC SULPHONAMIDES           $4,054,874
# K05A IRRIGATING SOLUTIONS             $3,620,448
# T01G RADIODIAGNOSTIC AGENTS           $3,216,200
# R03C N-STEROIDAL RESP A-INFL          $2,714,422
# A07X OTHER ANTIDIARRHOEALS            $2,320,079
# K01A ELECTROLYTE SOLN=>100ML          $2,174,818
# G01D GYNAECOLOG ANTISEPTICS           $1,858,737
# C05B VARICOSE THERAPY,TOPICAL         $1,377,375
# J06G SPECF IMM-GLOB ANTI-BACT         $1,332,386
# N06D NOOTROPICS                       $1,013,603
# C02B A-HYPERT(NON VEG)+DIURET           $738,118
# K01B STANDARD SOLUTIONS                 $693,645
# K01E AMINO-ACID SOLUTIONS               $637,357
# H03C IODINE PREPARATIONS                $617,472
# K02A DEXTRANS                           $425,073
# A02C OTH STOMACH DISORDER PRD           $275,215
# K07A PERFUSION SOLUTIONS                $156,979
# J01L CARBENICILLIN+SIMIL.TYPE             $9,267
# K04B STANDARD SOLUTION <100ML             $8,228
# P03B INSECTICIDES & REPELLENTS            $2,580
# C02C RAUWLF ALK+OTH A-HY HERB               $109
# K04C CALORIC SOLUTIONS <100ML                $89
# A03E A-SPASMA COMBINATIONS                   $50
# A10D ANIMAL INSULINS                        $nan
# A15A APPETITE STIMULANTS                    $nan
# J01B CHLORAMPHENICOLS + COMBS               $nan
# J01M RIFAMPICIN AND RIFAMYCIN               $nan
# S01N ANTICATARACTOGENICS                    $nan
#
# [313 rows x 7 columns]
